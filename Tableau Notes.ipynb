# %% [markdown]
# # Tableau Notes

# %% [markdown]
# First step, connect to file. csv is a 'text file'
#
# measures are numerical values, dependent variables
#
# dimensions are categorical, independent variables
#
# to create calculated field, right-click on measures, select calculated field
#
# to create color on a bar chart, drag category data field to 'color'
#
# to add totals to bars drag data field to 'labels'

# %%
from IPython.display import Image

# %%
Image('capture.png')

# %%
Image('capture1.png')
